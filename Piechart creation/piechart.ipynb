# %%
import pandas as pd
from matplotlib import pyplot as plt

data=pd.read_csv('C:\\Users\\njeri\\OneDrive\\Desktop\\Machine Learning\\music.csv')
gender_counts=data['genre'].value_counts()
#Count number of males and females in the dataset column gender

# %%
plt.pie(gender_counts,labels=['dancehall','jazz','classical','dance','acoustic'],autopct='%1.1f%%')
#plt.pie creates  the pie chart and its elements.autopct includes the percentages
plt.show()
